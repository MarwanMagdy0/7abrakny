# %% [markdown]
# <a href="https://colab.research.google.com/github/MarwanMagdy0/7abrakny/blob/master/YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Mar 22 21:54:04 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO
from IPython.display import display, Image
# !pip install roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="okIile5eMzHXgrVxXR7M")
project = rf.workspace("bottle-detection-f6qyg").project("car-dor")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.30, to fix: `pip install ultralytics==8.0.196`

# %%
import yaml

def remove_substring_from_paths(yaml_file):
    # Load the YAML file
    with open(yaml_file, 'r') as file:
        data = yaml.safe_load(file)

    # Modify the train and val paths
    data['train'] = "train/images"
    data['val']   = "valid/images"

    # Save the modified YAML file
    with open(yaml_file, 'w') as file:
        yaml.dump(data, file)

# Example usage
yaml_file = f"{dataset.location}/data.yaml"
remove_substring_from_paths(yaml_file)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="{dataset.location}/data.yaml" epochs = 100 imgsz=640 save_period=5
# Out:
# Ultralytics YOLOv8.1.30 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
